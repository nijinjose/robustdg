# %%
import os
import sys
import numpy as np
import argparse
import copy
import random
import json
import pickle
import matplotlib.pyplot as plt

# %%
# x=['ERM_Unf_Data', 'ERM', 'Weighted_ERM', 'Adapted_ERM']
print('Weights: ')
print('Angle 15: 2000')
print('Angle 30: 1800')
print('Angle 45: 1500')
print('Angle 60: 500')
print('Angle 75: 200')
x=['ERM_Unf_Data', 'ERM_Weighed_Data']
y_easy=[90.7, 90.4]
y_hard_left=[89.9, 85.5]
y_hard_right=[90.6, 93.2]
plt.errorbar(x, y_easy, yerr=[0.34, 0.73],  marker= 'o', label='Test-1')
plt.errorbar(x, y_hard_left, yerr=[2.30, 4.75], marker= 'o', label='Test-2')
plt.errorbar(x, y_hard_right, yerr=[1.32, 1.32], marker= 'o', label='Test-3')
plt.legend()
plt.ylabel('Test Accuracy')
plt.title('Synthetic Data Experiment')
# Out:
# Weights:
# Angle 15: 2000
# Angle 30: 1800
# Angle 45: 1500
# Angle 60: 500
# Angle 75: 200
# Text(0.5, 1.0, 'Synthetic Data Experiment')

# %%
ERM_Unf_Data
Model Param:  [[ 2.82070351 -0.02720232]] [[0.19291871 0.03752375]]
Model Bias:  -0.011233145138248801 0.00248323333635761

ERM_Weighted_Data
Model Param:  [[2.53439932 0.14196582]] [[0.15564551 0.03143359]]
Model Bias:  0.07806374318897724 0.008961881690486055

# %%
# x=['ERM_Unf_Data', 'ERM', 'Weighted_ERM', 'Adapted_ERM']
x=['ERM', 'Weighted ERM']
y=[91.8, 90.4]
plt.errorbar(x, y, yerr=[0.56, 0.96], marker= 'o', label='Test Domains: 0, 90')
plt.legend()
plt.ylabel('Test Accuracy')
plt.title('Rotated MNIST Experiment')
# Out:
# Text(0.5, 1.0, 'Rotated MNIST Experiment')

# %%
ERM
Perfect Match Score  :  15.479166666666666 0.8540548707326846
TopK Perfect Match Score  :  43.90833333333333 1.7426133790628613
Perfect Match Rank  :  34.127541666666666 1.5792181818774182
    
Weighted ERM
Perfect Match Score  :  14.570833333333333 0.9951095696231423
TopK Perfect Match Score  :  41.35 2.4672226287872743
Perfect Match Rank  :  36.92391666666666 2.843676523470784

# %%
[147 228 126  95 150 245 203  93 231 206]
[169, 104, 238,  78,  76, 249, 201, 136, 108,  57]

3.73693788 -0.3788294 (uniform)
3.94150708 -0.35525345 (weighted)
